# %%
# !python train.py --batch-size 512 --dataset 1 --epochs 600 --lr 0.001 > test_ori.txt
# Out:
# ...
# 100%|██████████| 1960/1960 [00:10<00:00, 193.97it/s]
#
# ...
# 100%|██████████| 840/840 [00:03<00:00, 215.69it/s]
# C:\Users\ADMIN\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\rnn.py:88: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# C:\Users\ADMIN\AppData\Roaming\Python\Python312\site-packages\torch\optim\lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#
# ...
